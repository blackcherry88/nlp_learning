# %%
import json
import random
import logging
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support
from spacy.gold import GoldParse
from spacy.scorer import Scorer
from sklearn.metrics import accuracy_score
import spacy

# %%
def convert_dataturks_to_spacy(dataturks_JSON_FilePath):
    try:
        training_data = []
        lines=[]
        with open(dataturks_JSON_FilePath, 'r') as f:
            lines = f.readlines()

        for line in lines:
            data = json.loads(line)
            text = data['content']
            entities = []
            for annotation in data['annotation']:
                #only a single point in text annotation.
                point = annotation['points'][0]
                labels = annotation['label']
                # handle both list of labels or a single label.
                if not isinstance(labels, list):
                    labels = [labels]

                for label in labels:
                    #dataturks indices are both inclusive [start, end] but spacy is not [start, end)
                    entities.append((point['start'], point['end'] + 1 ,label))


            training_data.append((text, {"entities" : entities}))

        return training_data
    except Exception as e:
        logging.exception("Unable to process " + dataturks_JSON_FilePath + "\n" + "error = " + str(e))
        return None

# %%
def train_spacy():

    TRAIN_DATA = convert_dataturks_to_spacy("traindata.json")
    nlp = spacy.blank('en')  # create blank Language class
    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if 'ner' not in nlp.pipe_names:
        ner = nlp.create_pipe('ner')
        nlp.add_pipe(ner, last=True)
       

    # add labels
    for _, annotations in TRAIN_DATA:
         for ent in annotations.get('entities'):
            ner.add_label(ent[2])

    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    with nlp.disable_pipes(*other_pipes):  # only train NER
        optimizer = nlp.begin_training()
        for itn in range(10):
            print("Statring iteration " + str(itn))
            random.shuffle(TRAIN_DATA)
            losses = {}
            for text, annotations in TRAIN_DATA:
                nlp.update(
                    [text],  # batch of texts
                    [annotations],  # batch of annotations
                    drop=0.2,  # dropout - make it harder to memorise data
                    sgd=optimizer,  # callable to update weights
                    losses=losses)
            print(losses)
            

    #test the model and evaluate it
    examples = convert_dataturks_to_spacy("testdata.json")
    tp=0
    tr=0
    tf=0

    ta=0
    c=0        
    for text,annot in examples:

        f=open("resume"+str(c)+".txt","w")
        doc_to_test=nlp(text)
        d={}
        for ent in doc_to_test.ents:
            d[ent.label_]=[]
        for ent in doc_to_test.ents:
            d[ent.label_].append(ent.text)

        for i in set(d.keys()):

            f.write("\n\n")
            f.write(i +":"+"\n")
            for j in set(d[i]):
                f.write(j.replace('\n','')+"\n")
        d={}
        for ent in doc_to_test.ents:
            d[ent.label_]=[0,0,0,0,0,0]
        for ent in doc_to_test.ents:
            doc_gold_text= nlp.make_doc(text)
            gold = GoldParse(doc_gold_text, entities=annot.get("entities"))
            y_true = [ent.label_ if ent.label_ in x else 'Not '+ent.label_ for x in gold.ner]
            y_pred = [x.ent_type_ if x.ent_type_ ==ent.label_ else 'Not '+ent.label_ for x in doc_to_test]  
            if(d[ent.label_][0]==0):
                #f.write("For Entity "+ent.label_+"\n")   
                #f.write(classification_report(y_true, y_pred)+"\n")
                (p,r,f,s)= precision_recall_fscore_support(y_true,y_pred,average='weighted')
                a=accuracy_score(y_true,y_pred)
                d[ent.label_][0]=1
                d[ent.label_][1]+=p
                d[ent.label_][2]+=r
                d[ent.label_][3]+=f
                d[ent.label_][4]+=a
                d[ent.label_][5]+=1
        c+=1
    for i in d:
        print("\n For Entity "+i+"\n")
        print("Accuracy : "+str((d[i][4]/d[i][5])*100)+"%")
        print("Precision : "+str(d[i][1]/d[i][5]))
        print("Recall : "+str(d[i][2]/d[i][5]))
        print("F-score : "+str(d[i][3]/d[i][5]))

# %%
spacy.prefer_gpu()
train_spacy()
# Out:
# Warning: Unnamed vectors -- this won't allow multiple vectors models to be loaded. (Shape: (0, 0))
# Statring iteration 0
# {'ner': 6024.980022157161}
# Statring iteration 1
# {'ner': 4156.934329157899}
# Statring iteration 2
# {'ner': 3471.2245884451604}
# Statring iteration 3
# {'ner': 2950.4357274090185}
# Statring iteration 4
# {'ner': 2647.330996542007}
# Statring iteration 5
# {'ner': 2372.3683268549976}
# Statring iteration 6
# {'ner': 2151.2988492280506}
# Statring iteration 7
# {'ner': 1874.086188932862}
# Statring iteration 8
# {'ner': 1677.6490600345708}
# Statring iteration 9
# {'ner': 1612.822831661878}
# /home/taohu/anaconda3/envs/pytorch/lib/python3.6/site-packages/sklearn/metrics/classification.py:1145: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
#  For Entity Name
#
# Accuracy : 99.83805668016194%
# Precision : 0.9983831936194594
# Recall : 0.9983805668016195
# F-score : 0.9981113185060555
#
#  For Entity Location
#
# Accuracy : 99.27125506072875%
# Precision : 0.9927657005623397
# Recall : 0.9927125506072875
# F-score : 0.9897446574315648
#
#  For Entity Email Address
#
# Accuracy : 99.43319838056681%
# Precision : 1.0
# Recall : 0.994331983805668
# F-score : 0.9971579374746244
#
#  For Entity Companies worked at
#
# Accuracy : 98.78542510121457%
# Precision : 1.0
# Recall : 0.9878542510121457
# F-score : 0.9938900203665988
#
#  For Entity Designation
#
# Accuracy : 99.83805668016194%
# Precision : 1.0
# Recall : 0.9983805668016195
# F-score : 0.9991896272285252
#
#  For Entity Graduation Year
#
# Accuracy : 99.83805668016194%
# Precision : 0.9983805668016195
# Recall : 0.9983805668016195
# F-score : 0.9983805668016195
#
#  For Entity College Name
#
# Accuracy : 100.0%
# Precision : 1.0
# Recall : 1.0
# F-score : 1.0
#
#  For Entity Skills
#
# Accuracy : 100.0%
# Precision : 1.0
# Recall : 1.0
# F-score : 1.0

# %%
# add labels
TRAIN_DATA = convert_dataturks_to_spacy("traindata.json")

# %%
for txt, annotations in TRAIN_DATA:
    for ent in annotations.get('entities'):
        print(f"L:{ent[2]} --> {txt[ent[0]:ent[1]]}")
# Out:
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Skills --> Languages: Core Java, Go Lang, Data Structures & Algorithms, Oracle
# PL-SQL programming, Sales Force with APEX.
# Tools: RADTool, Jdeveloper, NetBeans, Eclipse, SQL developer,
# PL/SQL Developer, WinSCP, Putty
# Web Technologies: JavaScript, XML, HTML, Webservice
#
# Operating Systems: Linux, Windows
# Version control system SVN & Git-Hub
# Databases: Oracle
# Middleware: Web logic, OC4J
# Product FLEXCUBE: Oracle FLEXCUBE Versions 10.x, 11.x and 12.x
# L:Companies worked at --> Oracle
# L:Skills --> APEX. (Less than 1 year), Data Structures (3 years), FLEXCUBE (5 years), Oracle (5 years),
# Algorithms (3 years)
#
# L:Graduation Year --> 2012
# L:College Name --> Adithya Institute of Technology
# L:Degree --> B.E in Computer Science Engineering
# L:Graduation Year --> 2012
# L:Companies worked at --> Oracle
# L:Designation --> Associate Consultant
# L:Companies worked at --> Oracle
# L:Designation --> Staff Consultant
# L:Companies worked at --> Oracle
# L:Designation --> Senior Consultant
#
# L:Companies worked at --> Cloud Lending Solutions
# L:Designation --> Senior Software Engineer
#
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Cloud Lending Solutions
# L:Email Address --> indeed.com/r/Govardhana-K/
# b2de315d95905b68
#
# L:Location --> Bengaluru
# L:Designation --> Senior Software Engineer
#
# L:Name --> Govardhana K
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Skills --> Functional Testing, Blue Prism, Qtp
#
# L:College Name -->
# Osmania University
#
# L:Degree --> B.Sc. in Computer Science
# L:College Name -->
# Osmania University
#
# L:Degree --> MCA
# L:Companies worked at --> Oracle
# L:Designation --> QA Analyst
# L:Location --> Hyderabad
# L:Companies worked at --> Oracle
# L:Designation --> Test Analyst
# L:Location --> Hyderabad
# L:Location --> Hyderabad
# L:Location --> Hyderabad
# L:Location --> Hyderabad
# L:Companies worked at --> Oracle
# L:Designation --> Test Analyst
# L:Companies worked at --> Oracle
# L:Designation --> QA Analyst
# L:Designation --> Manual and Automation testing.
# L:Years of Experience --> 6 Yrs
# L:Location --> Hyderabad
# L:Location --> Hyderabad
# L:Companies worked at --> Oracle
# L:Designation --> Test Analyst
# L:Name --> Harini Komaravelli
# L:Skills -->  Languages & Technologies: Python, R, SQL, NoSQL, Predictive Modelling,
# Market Basket Analysis, Sentimental Analysis, Clustering, Bash
# Scripting (Preliminary), Socket Programming, Java (Preliminary)
#
# • Tools: R Studio, Jupyter, GIT, Sublime, MATLAB, Linux, KVM, Virtual Box,
# Open VZ, Oracle SQL Developer, MySQL, MongoDB, Excel
# L:Email Address --> indeed.com/r/Hartej-Kathuria/04181c5962a4af19
# L:Skills --> Python (2 years), SQL. (1 year), NOSQL (1 year), R (2 years), Machine Learning (2 years)
#
# L:Graduation Year --> 2016
# L:College Name --> Manipal University
#
# L:Degree --> B. Tech in Electrical and Electronics in Embedded Systems
# L:Graduation Year --> 2018
# L:College Name --> Manipal University
#
# L:Degree -->
# Statistics and Probability
# L:Location --> Bengaluru
# L:Designation --> Data Analyst Intern
# L:Email Address --> indeed.com/r/Hartej-Kathuria/04181c5962a4af19
# L:Location --> Bengaluru
# L:Companies worked at --> Oracle Retail
#
# L:Designation --> Data Analyst Intern
# L:Name --> Hartej Kathuria
# L:Skills --> Languages: Core Java
# Front end/GUI Tools programming: Adobe Flex, GWT
# Database: Oracle 10g
# IDE: Eclipse, FlexBuilder
# FrameWorks: Spring(Basics), MVC frame work
# Operating System: Windows, Linux, Unix
# L:Graduation Year -->  2009
# L:College Name --> University College Of Engineering
# L:Degree --> Bachelor of Technology in Computer Science
# L:Graduation Year --> 2011
#
# L:College Name --> Birla Institute Of Technology
# L:Companies worked at --> Oracle Corporation
# L:Companies worked at --> Oracle Corporation
# L:Designation --> Associate Consultant
# L:Graduation Year --> 2011
#
# L:Companies worked at --> Oracle Corporation
# L:Designation --> Associate Consultant
# L:Companies worked at --> State Street
#
# L:Companies worked at --> Oracle Corporation
# L:Designation --> Associate Consultant
# L:Email Address -->  indeed.com/r/Ijas-
# Nizamuddin/6748d77f76f94eed
# L:Location --> Irinchayam B.O
# L:Companies worked at --> State Street
#
# L:Designation --> Associate Consultant
# L:Name --> Ijas Nizamuddin
# L:Skills --> rogramming Languages :C/C++, angular, java, java servlet, HTML, java script, MySQL, css, jsff.
#
# Operating Systems Linux, Windows, Android
#
# ORM Eclipse Link, Hibernate
#
# Framework & tools :ADF, Eclipse, Android Studio, Git, Selenium, Code blocks, Net beans, R studio,
# Tortoise SVN.
# L:Skills --> JAVA (1 year), CSS (1 year), HTML (1 year), MYSQL (1 year), JAVASCRIPT (Less than 1 year),
# Angularjs (1 year), Oracle Pl/Sql
#
# L:Graduation Year -->  2009
# L:College Name --> Rashtriya Military School Bangalore
# L:Degree --> CBSE in Mathematics and English
#
# L:College Name --> Rashtriya Military School Bangalore
# L:Graduation Year -->  2016
# L:Location --> Pune
# L:College Name --> Army institute of technology
# L:Degree --> Bachelor of Enginerring in Information Technology
# L:Graduation Year -->  2016
# L:Location --> Pune
# L:Companies worked at --> Oracle Financial Software Services
# L:Designation --> Application Developer
# L:Location --> Pune
# L:Location --> Pune
# L:Designation --> java developer
# L:Name --> Imgeeyaul Ansari
# L:Graduation Year --> 2011
# L:Degree --> State Board
# L:Graduation Year --> 2013
# L:Graduation Year --> 2011
# L:College Name --> Acharya College Chembur
# L:Degree --> HSC in Computer science
#
# L:Graduation Year --> 2017
# L:College Name --> Saraswati College Of Engineering
# L:Degree --> BE (Computer Science) in Computer Science
#
# L:Skills --> Capable and Hardworking
# L:Graduation Year --> 2011
# L:Graduation Year --> 2011
# L:Skills --> SQL Oracle -
# L:Companies worked at --> NIIT
# L:Email Address --> Indeed: indeed.com/r/Jay-
# Madhavi/1e7d0305af766bf6
# L:Location --> Navi Mumbai
# L:Name --> Jay Madhavi
# L:Graduation Year --> 2011
# L:College Name --> AG&SGS Intermediate College
# L:Graduation Year --> 2014
# L:College Name --> Degree College
# L:Degree --> B.com
#
# L:Companies worked at --> SAP FICO
# L:Companies worked at --> SAP FICO
# L:Companies worked at --> SAP FICO
# L:Companies worked at --> SAP FICO
# L:Designation --> FI/CO Consultant in Tech Mahindra
# L:Skills --> Finance
# • Financial Accounting- General Ledger Accounting FI-G/L (New GL),
# • Accounts Payable-FI-A/P,
# • Accounts Receivable FI-A/R
# L:Companies worked at --> SAP FICO
# L:Years of Experience -->  3.2-years
# L:Email Address -->  indeed.com/r/Jitendra-Babu/bc3ea69a183395ed
# L:Location --> Chennai
# L:Companies worked at --> SAP FICO
# L:Designation --> FI/CO Consultant in Tech Mahindra
# L:Name --> Jitendra Babu
# L:Skills --> ITIL foundation
# L:College Name --> Biju Patnaik University
# L:Degree --> B. Tech in Electronics and Communication
#
# L:Companies worked at --> Sap labs
# L:Designation -->
# Associate consultant
# L:Companies worked at --> Sap labs
# L:Designation -->
# Associate consultant
# L:Email Address --> indeed.com/r/Jyotirbindu-
# Patnaik/77e3ceda47fbb7e4
#
# L:Location --> Bengaluru
# L:Designation -->
# Associate consultant
# L:Name --> Jyotirbindu Patnaik
# L:Skills --> Consistent
# L:Skills --> Hard working
# L:Skills -->  Flexible
# L:Skills --> Ability to quick grasp the concepts
# L:Skills --> Destructive Testing (Less than 1 year), FORGE (Less than 1 year), Non-Destructive (Less than 1
# year), Non-Destructive Testing (Less than 1 year), quality control (Less than 1 year)
#
# L:College Name --> Hr. Sec. School
#
# L:Location --> Rajapalaiyam
# L:College Name --> Tamil Nadu Board Of Education
# L:College Name --> Velammal Engineering College
# L:Degree --> B E in Production Engineering
# L:Companies worked at --> Infosys Limited
# L:Companies worked at --> Infosys Limited
# L:Designation --> Systems Engineer
# L:Email Address --> indeed.com/r/Karthihayini-
# C/627254c443836b3c
# L:Location --> Rajapalaiyam
# L:Companies worked at --> Infosys Limited
#
# L:Companies worked at --> Infosys Limited
# L:Designation --> Systems Engineer
# L:Name --> Karthihayini C
# L:Skills --> Program Management (2 years), Product Management (2 years), Quality Assurance (10+
# years), Business intelligence, Devops
#
# L:Graduation Year --> 2018
# L:College Name --> Narsee Monjee Institute of Management Studies
# L:Degree --> PGDBM
# L:Location --> Hyderabad
# L:Companies worked at --> Microsoft India
# L:Designation --> Sr Test Engineer
# L:Location --> Hyderabad
# L:Companies worked at --> Microsoft India
# L:Designation --> Sr consultant
# L:Location --> Hyderabad
# L:Companies worked at --> Microsoft India
# L:Designation --> Architect
# L:Graduation Year --> 2018
# L:Companies worked at --> Microsoft India
# L:Location --> Hyderabad
# L:Companies worked at --> Microsoft India
# L:Designation --> Architect
# L:Location --> Hyderabad
# L:Companies worked at --> Microsoft India
# L:Designation --> Architect
# L:Name --> Karthik GV
# L:Skills --> Operating systems: Windows […] 8, 10.
# Languages: C, C++, C#
#
# PROFESSIONAL SKILL SET:
#
# • Good Communication Skills in English and Hindi.
# • Ability to work under pressure.
# L:Skills --> SAP Security
# L:College Name --> Lovely Public Sr. Sec. School
# L:Degree --> CBSE
# L:Graduation Year --> 2011
# L:College Name --> Lovely Public Sr. Sec. School
# L:Degree --> CBSE
# L:Graduation Year --> 2015
# L:College Name --> Northern India engineering college, IP UNIVERSITY DELHI
# L:Degree --> B.Tech in Engineering
#
# L:Graduation Year --> 2015
# L:Skills --> SAP Systems: SAP ECC 6.0.
# Product Tools: GRC 10.1
# Database: Oracle, SQL, RDBMS.
# L:Location --> Delhi
# L:Location --> Delhi
# L:Designation --> Systems Engineer
# L:Location --> Delhi
# L:Skills --> SAP Security
# L:Companies worked at -->  Infosys Ltd
# L:Designation --> Systems Engineer
# L:Skills --> SAP Security
# L:Degree --> B.Tech in Information Technology
# L:Email Address --> indeed.com/r/Kartik-Sharma/cc7951fd7809f35e
#
# L:Location --> Delhi
# L:Location --> Delhi
# L:Companies worked at -->  Infosys Ltd
# L:Designation --> Systems Engineer
# L:Name --> Kartik Sharma
# L:Companies worked at --> Cisco
# L:Skills --> • Programming Languages: Python, XML
# • Database: Maria-DB, sql
# • Cisco Monitoring Tools: EM7
# • Operating Systems: Windows/XP
# • Reporting Tools: Vportal, Splunk
# • Application & Web Servers: Sciencelogic (EM7), Syslog sender, Relay server.
# • Data Structure Knowledge: Intermediate
# L:Skills --> Database (3 years), Python (3 years), Splunk (Less than 1 year), SQL (3 years), xml (3 years)
#
# L:Graduation Year --> 2012
# L:College Name --> rajasthan University
#
# L:College Name --> Compucom Insitute of Information Technology
#
# L:Companies worked at --> Cisco
# L:Designation --> Team Member
# L:Companies worked at --> Cisco
# L:Companies worked at --> Cisco
# L:Companies worked at --> Cisco
# L:Companies worked at --> Cisco
# L:Designation --> Team Member
# L:Location --> Bengaluru
# L:Companies worked at --> Cisco
# L:Companies worked at --> Cisco
# L:Email Address --> Indeed: indeed.com/r/Kasturika-
# Borah/9e71468914b38ee8
# L:Location --> Bengaluru
# L:Companies worked at --> Cisco
# L:Designation --> Team Member
# L:Name --> Kasturika Borah
# L:Graduation Year --> 2014
# L:College Name --> REiume Institute of road
# L:Degree --> Bachelor of Engineering in Information Technology
# L:Degree --> Foundation Training Program in Networking
#
# L:Companies worked at --> Infosys Limited
#
# L:College Name --> Networking, Infosys Limited
# L:Email Address --> indeed.com/r/Kavitha-K/8977ce8ce48bc800
# L:Graduation Year --> 2014
# L:Email Address --> indeed.com/r/Kavitha-K/8977ce8ce48bc800
# L:Location --> Salem
# L:Companies worked at --> Infosys Limited
#
# L:Designation --> Senior System Engineer
# L:Name --> Kavitha K
# L:Skills --> Microsoft office, Libreoffice
# L:Skills --> Microsoft office
# L:Skills --> UART
# L:Skills --> Understanding of UART, AMBA protocol
# L:Skills --> coding
# L:Skills --> Knowledge of RTL coding, FSM based designs
# L:Skills --> HDL
# L:Skills --> Verilog HDL
# L:Skills --> UART
# L:Skills --> MS
# OFFICE
# L:Skills --> Microsoft office
# L:Skills --> HDL
# L:Skills --> coding
# L:College Name --> Vidyodaya P.U. College
# L:College Name --> Visvesvaraya Technological University
#
# L:College Name --> Srinivas Institute of Technology
# L:Degree --> Bachelor of Engineering in Engineering
# L:College Name --> Manipal Academy of Higher Education
# L:Email Address --> indeed.com/r/Kavya-U/049577580b3814e6
# L:College Name --> School Of Information Sciences
#
# L:Degree --> Master of Science in Technology in Technology
#
# School Of Information Sciences
# L:Graduation Year --> 2007
# L:College Name --> Little Rock Indian School
#
# L:Skills --> HDL
# L:Skills --> Verilog HDL
# L:Skills --> coding
# L:Location --> Bengaluru
# L:Companies worked at --> Accenture
# L:Designation --> Network Ops Associate
#
# L:Email Address --> indeed.com/r/Kavya-U/049577580b3814e6
# L:Location --> Bengaluru
# L:Name --> Kavya U.
# L:Skills --> ANDROID (Less than 1 year), CISCO (Less than 1 year), NETWORKING (Less than 1 year)
# L:College Name --> Silver Bells Public School -  Muzaffarnagar, Uttar Pradesh
# L:College Name --> Paratap Public School -  Karnal, Haryana
# L:Graduation Year --> 2017
# L:College Name --> MM University
# L:Degree --> B.Tech in CSE
# L:Companies worked at --> SAP ABAP
# L:Location --> Noida
# L:Location --> Noida
# L:Companies worked at --> SAP ABAP
# L:Designation --> Developer
# L:Email Address --> indeed.com/r/Khushboo-Choudhary/
# b10649068fcdfa42
#
# L:Location --> Noida
# L:Designation --> Developer
# L:Name --> Khushboo Choudhary
# L:Graduation Year --> 2016
# L:Skills --> network engineers, Networking, CCNA, knowledge of Active Directory, DHCP, DNS ,
# Troubleshooting and fix Network related issues (2 years)
#
# L:Graduation Year --> 2016
# L:College Name --> SSVPS’s Late B. S. Deore College of Engineering
# L:Degree --> BE in computer science
# L:Graduation Year --> 2016
# L:Location --> Thane
# L:Companies worked at --> SAP -
# L:Designation --> Technical Support Engineer
# L:Email Address --> indeed.com/r/kimaya-
# sonawane/1f27a18d2e4b1948
# L:Location --> Thane
# L:Name --> kimaya sonawane
# L:Skills --> Jira, Ansible, Jenkins, Splunk, Nagios, Docker, Python, AWS, Bamboo, Linux, Git, Chef, Windows,
# Powershell Scripting
#
# L:Graduation Year --> 2008
#
# L:College Name --> Sister Nivedita School
# L:Graduation Year --> 2010
# L:Location --> Hyderabad
# L:Degree --> Board of Intermediate education
# L:Degree --> Secondary School Certificate in education
#
# L:Graduation Year --> 2014
# L:Graduation Year --> 2010
# L:College Name --> Lovely Professional University
# L:Degree --> Bachelor Of Engineering in Mechanical Engineering
# L:Email Address --> indeed.com/r/Koushik-Katta/a6b19244854199ec
# L:Graduation Year --> 2014
# L:Companies worked at --> Infosys limited
# L:Designation --> DEVOPS ADMINISTRATOR
# L:Skills --> Atlassian Tools: Jira, Confluence
# Configuration Management: Ansible /Chef
# CI Tools: Jenkins
# Monitoring Tools: Nagios
# Cloud: AWS
# Containerization: Docker
# Build Tools: Bamboo\Maven
# Log Tools: Splunk
# Databases: RDBMS, MYSQL, Oracle Database
# Programming Languages: Python and Java
# Scripting: Power Shell
# Operating Systems: Windows, Linux family, Redhat Linux
# Middleware: Websphere, Tomcat, Websphere MQ
# L:Graduation Year --> 2014
# L:Location --> Hyderabad
# L:Graduation Year --> 2014
# L:Location --> Hyderabad
# L:Companies worked at --> Infosys limited
# L:Email Address --> indeed.com/r/Koushik-Katta/a6b19244854199ec
# L:Location --> Hyderabad
# L:Name --> Koushik Katta
# L:Skills --> DHCP (Less than 1 year), DNS (Less than 1 year), EXCHANGE (Less than 1 year), exchange
# (Less than 1 year), LAN (Less than 1 year)
#
# ADDITIONAL INFORMATION
#
# SKILLS:-
#
# • Messaging: MS exchange, Lotus client and MS outlook issue coordination to user.
#
# • Users / Share folders creation and permission assigning.
#
# • Networking: TCP/IP, DNS, DHCP, and LAN/WAN.
#
# • Monthly patching update activity and server owner approval / RFC follow-ups.
# L:College Name --> inDR N.G.P ARTS AND SCIENCE COLLEGE
# L:Degree --> Bachelor of computer science in computer science
#
# L:Companies worked at -->
# Cisco
# L:Designation --> Certified Network Associate Training Program
# L:Email Address --> indeed.com/r/Kowsick-
# Somasundaram/3bd9e5de546cc3c8
# L:Location --> Erode
# L:Designation --> Certified Network Associate Training Program
# L:Name --> Kowsick Somasundaram
# L:Skills -->
# SAPUI5 (2 years), CSS. (2 years), EMPLOYEE RESOURCE GROUP (2 years), ENTERPRISE
# RESOURCE PLANNING (2 years), SAP ABAP (2 years)
#
# ADDITIONAL INFORMATION
#
# Technical skills
# Languages SAPUI5 (Primary Skill),
# ABAP/4, C, C++, HTML, CSS, JavaScript, PHP,
# jQuery, Ajax.
# ERP SAP R/3 in 4.7, 5.0 (E)
# Operating Systems Windows
# Database MySQL, Oracle
# L:Location --> Bengaluru
# L:Companies worked at -->  Infosys Limited
# L:Designation --> Senior Systems Engineer
# L:Location --> Bengaluru
# L:Designation --> Senior Systems Engineer
# L:Location --> Bengaluru
# L:Designation --> Senior Systems Engineer
# L:Email Address --> indeed.com/r/Lakshika-
# Neelakshi/27b31f359c52ef76
# L:Location --> Bengaluru
# L:Companies worked at -->  Infosys Limited
# L:Designation --> Senior Systems Engineer
# L:Name --> Lakshika Neelakshi
# L:Graduation Year --> 2014
# L:Graduation Year --> 2014
# L:Skills --> Tools: Manual Testing, Selenium (Selenium IDE, Selenium Web Driver), Eclipse IDE.
# Languages: C, Core Java
# Database: SQL
# Operating Systems: Windows XP, 7, 8
# Management Tool: HP Quality Center
# Defect Tracking Tool: JIRA
# L:College Name --> Padmavani High School
#
# L:Graduation Year --> 2010
# L:College Name --> Vani Jr college
# L:Graduation Year --> 2014
# L:College Name --> Kuppam Engineering College
# L:Degree --> B-Tech
# L:Designation --> Software Test Engineer
#
# L:Graduation Year --> 2014
# L:Graduation Year --> 2014
# L:Designation --> Software Test Engineer
#
# L:Graduation Year --> 2014
# L:Graduation Year --> 2014
# L:Graduation Year --> 2014
# L:Graduation Year --> 2014
# L:Companies worked at --> Infosys Limited
# L:Designation --> Software Test Engineer
#
# L:Graduation Year --> 2014
# L:Graduation Year --> 2014
# L:Companies worked at --> Infosys Limited
# L:Companies worked at --> Infosys Limited
# L:Email Address --> indeed.com/r/Madas-
# Peddaiah/557069069de72b14
#
# L:Location --> Anantapur
# L:Name --> Madas Peddaiah
# L:Skills --> LINUX (4 years), UNIX (4 years), ospf (4 years), bgp (4 years), mpls (4 years), ipsec (4 years),
# multicast (4 years), l2vpn (4 years), l3vpn (4 years), tcl (4 years), python (2 years)
#
# L:College Name --> Rajah college
#
# L:Degree --> S.S.C in computer science
# L:College Name --> PES college
# L:Degree --> Master degree in computer science in computer science
# L:Companies worked at --> Cisco
# L:Companies worked at --> Cisco
# L:Companies worked at --> Wipro
# L:Designation --> Senior software engineer
#
# L:Designation --> Senior project engineer
# L:Companies worked at --> Wipro
# L:Companies worked at --> Cisco
# L:Companies worked at --> Cisco
# L:Designation --> Senior project engineer
# L:Companies worked at --> Wipro
# L:Designation --> Senior project engineer
# L:Years of Experience --> 4 year
# L:Email Address --> Indeed: indeed.com/r/Madhuri-
# Sripathi/04a52a262175111c
#
# L:Location --> Banglore
# L:Name --> Madhuri Sripathi
# L:Skills -->
# • Desk Manuals/Business Process & Navigation Documentation
# • Business Ethics
# • Professional Communication
# • Reporting Tools & Microsoft Office Applications
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Skills --> BCP (6 years), Data Governance (6 years), Data Management (6 years), Oracle (6 years),
# Reporting Tools (6 years)
#
# ADDITIONAL INFORMATION
#
# Key Skills
# • Process Management & Improvement
# • Operations & Team Management
# • Data Governance & Automation
# • Oracle E- Business Systems experience in Supplier Data/Vendor Data management
# • BCP Policies & Procedures
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Email Address --> indeed.com/r/Mahesh-Vijay/a2584aabc9572c30
# L:Companies worked at --> Oracle
# L:Graduation Year --> 2004
# L:College Name --> Vivekananda PU College
# L:Graduation Year --> 2007
# L:College Name --> Vivekananda Degree College, Bangalore
# University
# L:Degree --> Bachelors in Commerce (B.Com)
# L:Location --> Bengaluru
# L:Companies worked at --> Oracle
# L:Designation --> Senior Analyst -Supplier Data Management
# L:Companies worked at --> Oracle
# L:Designation --> Lead Analyst -SME -Supplier Data Management
#
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Designation --> Team lead
# L:Graduation Year --> 2007
# L:Companies worked at --> Oracle
# L:Designation --> Team lead
# L:Companies worked at --> Oracle
# L:Years of Experience --> 6.5 years
# L:Email Address --> indeed.com/r/Mahesh-Vijay/a2584aabc9572c30
# L:Location --> Bengaluru
# L:Name --> Mahesh Vijay
# L:Skills --> Uft/qtp,alm/qc,jira,jenkins,automation testing,cicd,service vitualization,uipath
#
#
#
# ADDITIONAL INFORMATION
#
# Operating Systems Windows 10 / 8 / 7 / Vista / XP
#
# Domains Banking and Finance
#
# Frameworks Data driven framework, Keyword driven framework
#
# Tools HP-UFT, HP-SV, HP-ALM/QC, SOAP UI, JENKINS, UiPath
#
# Methodologies STLC, Agile and waterfall.
#
# Project Management Tools JIRA
#
# TECHNICAL SKILLS
#
# • 2.5+years of professional experience in SQL.
# • Has hands on experience on Oracle DB (Oracle 11g)
# • Has extensive knowledge of Testing Procedures and various
# phases of Testing Has 2+ years of experience on QC/ALM
# • Has 2+ years working experience in API & GUI testing
# using HP UFT. Has 4 months of experience with uiPath
# • Has 2+ years working experience in SOAP UI.
# • Has 1.5+ year working experience on service virtualization using HP SV tool.
# • Has 6 months working experience in JIRA during work under agile methodology.
# • Has undergone Infosys Training in .Net Testing.
# • Has knowledge about CICD (Continuous integration and continuous delivery)
#
# PROJECT UNDERTAKEN
#
# DI-Middleware testing (August 14 -
# July 17) Domain- Accounts and customer.
# Client- ABN AMRO Bank (Netherland's bank)
# Project Name- ESB (Enterprise service bus)
# • Tools- ALM, SQL Developer, HP UFT, HP SV, SOAP UI, JENKINS, JIRA.
# In this project, we were validating end to end communication of consumer & provider via ESB.
# What consumer actually
# sent to the Provider and how provider responds to the consumer. Testing included System
# Integration Testing,
# Regression Testing, GUI Testing and Reports.
# L:Graduation Year --> 2013
# L:College Name --> Meghnad saha institute of technology
#
# L:Degree --> B.Tech in CSE
# L:Designation --> Software Automation Engineer
#
# L:Location --> Pune,
# L:Years of Experience --> 3.5 years
# L:Email Address --> indeed.com/r/Manisha-Bharti/3573e36088ddc073
#
# L:Location --> Pune,
# L:Designation --> Software Automation Engineer
#
# L:Name --> Manisha Bharti
# L:Companies worked at --> Accenture
# L:Skills --> QA (7 years), TESTING (6 years), ESTIMATION (6 years), AMDOCS (Less than 1 year), BILLING
# (Less than 1 year)
#
# ADDITIONAL INFORMATION
#
# SKILLS AND COMPETENCIES
# Domain and Functional Expertise Tools and Languages:
# • Telecommunications and IPTV Systems • NetCracker, NetProvision, Insight (IISY), HDM (Nokia),
# Trouble Ticketing
# • Test/QA Lead • Click Schedule, FieldLink, AMDOCS-Ordering, Billing - Product Catalog
# • Project Management • IBM - TOCP, Mediaroom, MediaFirst TV3 platform (Ericsson)
# • Software Testing and Defect Management • HP QC 10, JIRA, TDP, Accenture Test Estimation Tool
# • Lead to Order and Order to Cash Management • Caliber RM (Requirement Gathering),
# Confluence, Clear Quest
# • Service Provisioning and Activation • Worksoft Certify, QTP, Java, Selenium, SQL, HTML, XML
# • Business Analysis (Requirement Management) • Splunk, WinSCP, SOAP UI, Kibana, Wireshark
# • Automation • Proficiency in MS Office (Word, Excel, PowerPoint and Visio)
# L:College Name --> Canossa Convent School
#
# L:Graduation Year --> 2007
# L:College Name --> Canossa Convent Girls Inter College
#
# L:Graduation Year --> 2011
# L:College Name --> Amity University
# L:Degree --> B.TECH. in Information Technology
#
# L:Companies worked at --> Accenture
# L:Companies worked at --> Accenture
# L:Graduation Year --> 2011
# L:Location --> Bengaluru
# L:Companies worked at --> Accenture
# L:Designation --> Senior Software Analyst
# L:Location --> Bengaluru
# L:Companies worked at --> Accenture
# L:Designation --> Senior Software Analyst
# L:Email Address --> indeed.com/r/Manjari-Singh/fd072d33991401f0
#
# L:Location --> Bengaluru
# L:Companies worked at --> Accenture
# L:Designation --> Senior Software Analyst
# L:Name --> Manjari Singh
# L:Graduation Year --> 2013
# L:Skills --> Active Directory (2 years), Microsoft office, Windows,End user computing (3 years)
# L:College Name --> Rajiv Gandhi Institute of Technology
# L:College Name --> Al-Ameen PU College
# L:Graduation Year --> 2013
# L:Location --> Bengaluru
# L:College Name --> Visveswaraiah Technological University
# L:Degree --> B.E in Electronics & Communication
#
# L:Companies worked at --> Accenture
# L:Companies worked at --> Accenture
# L:Designation --> IT Operations Analyst
# L:Location --> indeed.com/r/Mohamed-Ameen/
# ba052bfa70e4c0b7
#
# L:Location --> Bengaluru
# L:Designation --> System engineer
# L:Name --> Mohamed Ameen
# L:Location --> Gurgaon
# L:Skills --> active directory, iis, sccm, dhcp, sql, wsus, dns
#
# ADDITIONAL INFORMATION
#
# Computer Skills
# ● MS Office Tools: MS Excel, MS Word, MS Power Point.
# ● Hands on experience on all versions of Windows.
# ● Sound knowledge of internet and networking.
# ● Coding Languages: C, C++, Java.
# L:College Name --> KIIT college of Engg.
# L:Email Address --> indeed.com/r/Mohini-Gupta/08b5b8e1acd8cf07
# L:Degree --> B.tech
# L:Companies worked at --> Microsoft
# L:Companies worked at --> Microsoft
# L:Designation --> Server Support Engineer
# L:Email Address --> indeed.com/r/Mohini-Gupta/08b5b8e1acd8cf07
# L:Location --> Gurgaon
# L:Designation --> Server Support Engineer
# L:Name --> Mohini Gupta
# L:Skills --> SKILL SET • ASP.NET, C# • QA tools
#
# • Coding and modularization • Excellent communication skills
#
# • VB, VB.net, ASP • Technical specifications creation
#
# • HTML • System backups
#
# • Sql server 2005, Oracle • System upgrades
#
# • Java/C/C++ • Excellent problem-solving abilities
#
# Navas Najeer Koya 3
# L:Location --> Mangalore
# L:Skills --> C# (Less than 1 year), .NET, SQL Server, Css, Html5
#
# L:Graduation Year -->  2014
# L:Location --> Mangalore
# L:Location --> Mangalore
# L:Degree --> Bachelor of Computer Application
# L:Graduation Year -->  2014
# L:Companies worked at --> Infosys
# L:Designation --> Test Engineer
#
# L:Companies worked at --> Infosys
# L:Designation --> Test Engineer
#
# L:Graduation Year -->  2014
# L:Companies worked at --> Infosys
# L:Designation --> System Engineer
# L:Location --> Mangalore
# L:Location --> Mangalore
# L:Designation --> Test Engineer
#
# L:Name --> Navas Koya
# L:Skills -->  Basic Computers knowledge
# ● Good Understanding of Business Ethics, Operational Research.
# ● Completed Project Work on working capital with A+ Grade.
# L:Graduation Year --> 2015
# L:College Name --> Guru Nanak English High School and Jr cllg
# L:Degree --> H.S.C
# L:Graduation Year --> 2018
# L:Graduation Year --> 2015
# L:College Name --> Vedanta College of management and information technology
# L:Degree --> TYBMS in Management Studies
# L:Location --> Ulhasnagar
# L:Companies worked at --> Accenture
# L:Designation --> fresher job
# L:Email Address --> indeed.com/r/Navjyot-Singh-Rathore/
# ad92079f3f1a4cad
# L:Location --> Ulhasnagar
# L:Name --> Navjyot Singh Rathore
# L:College Name --> UPTU. India
# L:Degree --> Master of Computer Application
# L:Graduation Year --> 2015
# L:Skills --> • Trained on SAP S4 HANA.
# • Having knowledge of Code Push down, CDS view and it's consumption in ABAP.
# • Data Modeling, creation of different type of views.
# • AMDP.
# • ADBC connectivity.
# • Familiar with SQL, DDL, DML syntaxes.
# • Work on Windows 7, Windows XP, Windows 8, Windows 10 OS, can work on C, C++
# L:Skills --> SAP (2 years), ABAP (2 years), ADBC (Less than 1 year), C++ (Less than 1 year), DATA
# MODELING (Less than 1 year)
# L:Companies worked at --> SAP ABAP
# L:Designation --> Consultant
# L:Companies worked at --> SAP ABAP
# L:Designation --> Consultant
# L:Email Address --> indeed.com/r/Nazish-Alam/
# b06dbac9d6236221
# L:Location --> Ghaziabad
# L:Companies worked at --> SAP ABAP
# L:Designation --> Consultant
# L:Name --> Nazish Alam
# L:Skills --> Technical Experience: - Automation Testing (REST API, Service Virtualization), Functional Testing,
# Regression Testing
# Manual Testing, Scripting (SQL)
# Domain Experience: - Telecom, Banking
# Programming & Scripting Languages: - HTML, CSS, XML, SQL, JAVA (Basic), JSON
# SDLC Model: -Waterfall, Agile
# Testing Tools: - CA LISA, APM (Amdocs Process Manager), SOAP UI, TOSCA, HP-ALM (QC)
# Test Management Tools: -JIRA, Quality Center
# Other Tools: -SQL Developer, TOAD.
# Database: - DB2, SQL
# L:Skills --> API. (1 year), Scripting. (1 year), SOAP (1 year), UI (1 year), XML (3 years)
#
# L:College Name --> Central India Institute
#
# L:Degree --> Bachelor in Electronics
# L:Graduation Year -->
# 2008
#
#
# L:Degree --> State Board
# L:Email Address --> indeed.com/r/Nidhi-Pandit/b4b383dbe14789c5
# L:Designation --> Test Engineer
# L:Designation --> Test Engineer
# L:Designation --> Test Engineer
# L:Email Address --> indeed.com/r/Nidhi-Pandit/b4b383dbe14789c5
# L:Companies worked at --> Infosys Limited
#
# L:Designation --> Test Engineer
# L:Name --> Nidhi Pandit
# L:Skills --> Platform business model, Behaviour design
#
# L:Skills --> Python, Django, Celery, Java, AngularJS, HTML, Bootstrap 3, Shell Script, MySQL, MongoDB,
# Ubuntu
# L:Skills --> Django (6 years), Java (3 years), MongoDB (3 years), MySQL (3 years), Python (6 years)
# L:Graduation Year --> 2012
# L:Location --> Bengaluru
# L:College Name --> IIIT
# L:College Name --> VIT
# L:Degree --> M.Tech. in IT
# L:Companies worked at --> Infosys
# L:Designation --> System Engineer
# L:Graduation Year --> 2012
# L:Graduation Year --> 2012
# L:Companies worked at --> Cisco
# L:Companies worked at --> Cisco
# L:Graduation Year --> 2012
# L:Location --> Bengaluru
# L:Companies worked at --> Cisco
# L:Designation --> Software Engineer
# L:Companies worked at --> Aggrigator
# L:Location --> Bengaluru
# L:Companies worked at --> Aggrigator
# L:Designation --> Product Development
#
# L:Email Address --> indeed.com/r/Nikhileshkumar-Ikhar/
# cb907948c3299ef4
#
# L:Location --> Bengaluru
# L:Degree --> M.Tech. in IT
# L:Years of Experience -->  7+ years
# L:Designation --> Product development engineer
# L:Name --> Nikhileshkumar Ikhar
# L:Skills --> • Programming Language: core java, peoplecode.
# • Scripting languages: PHP, JavaScript.
# • Web Languages: HTML, CSS.
# • Database Language: Sql.
# • Frameworks: Bootstrap, JQuery.
# • IDE's: NetBeans, Eclipse.
# • Tools: Application Designer, Toad.
# L:Skills --> Php, Html5, Javascript, Css, Bootstrap, Jquery, Sql
# L:College Name --> Vijaya High School
# L:Degree --> e-commerce
# L:College Name --> Vijaya composite p.u. college
# L:Graduation Year -->
# 2017
# L:College Name --> Vtu
# L:Degree --> Btech information science in BCET
#
# L:Degree --> e-commerce
# L:Email Address --> indeed.com/r/Nitin-Tr/e7e3a2f5b4c1e24e
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Designation -->
# PeopleSoft consultant
#
# L:Degree --> e-commerce
# L:Degree --> e-commerce
# L:Email Address --> indeed.com/r/Nitin-Tr/e7e3a2f5b4c1e24e
# L:Location --> Bangalore Urban
# L:Name --> Nitin Tr
# L:Skills --> REST
# L:Skills --> Angular JS
# L:Skills --> DOJO
# L:Skills --> CSS
# L:Skills --> HTML
# L:Skills --> HTML
# L:Skills --> SVN
# L:Skills --> Code Collaborator
# L:Skills --> WinSCP
# L:Skills --> SSH
# L:Skills --> Eclipse
# L:Skills --> UNIX
# L:Skills --> Windows (7, XP)
# L:Skills --> Oracle
# L:Skills --> OOJS
# L:Skills --> JavaScript
# L:Skills --> Core Java
# L:Graduation Year --> 1980
# L:College Name --> Institute of Road and Transport May
# L:Degree --> B.Tech
#
# L:Skills --> HTML
# L:Skills --> CSS
# L:Skills --> DOJO
# L:Skills --> JAVASCRIPT
# L:Designation --> SYSTEMS ENGINEER
# L:Designation --> INDUSTRY BANKING
# L:Skills --> DOJO
# L:Email Address --> indeed.com/r/Pradeeba-V/19ff20f4b8552375
# L:Skills --> HTML
# L:Skills --> CSS
# L:Skills --> DOJO
# L:Skills --> JAVASCRIPT
# L:Designation --> SYSTEMS ENGINEER
# L:Designation --> SENIOR SYSTEMS ENGINEER
# L:Designation --> INDUSTRY FINACLE - BANKING
# L:Skills --> REST
# L:Skills --> HTML
# L:Skills --> Code Collaborator
# L:Skills --> SVN
# L:Skills --> Angular JS
# L:Skills --> DOJO
# L:Skills --> REST
# L:Skills --> CSS3
# L:Skills --> CSS
# L:Skills --> HTML5
# L:Skills --> HTML
# L:Skills --> OOJS
# L:Skills --> JAVASCRIPT
# L:Companies worked at --> CISCO
# L:Designation --> LEAD ENGINEER
# L:Email Address --> indeed.com/r/Pradeeba-V/19ff20f4b8552375
# L:Companies worked at --> CISCO
# L:Designation --> LEAD ENGINEER
# L:Name --> Pradeeba V
# L:Skills --> • Good communication - written and oral skills
# • Excellent conceptual and analytical skills
# • Effective interpersonal skills
#
# PERSONALITY
# • Communicative • Punctuality
# • Creativity • Organized
# L:Skills --> Java, Jsp, Html, Sql, C++, Javascript
# L:College Name --> Notre Dame Academy
# L:Degree --> C.B.S.E.
#
# L:Graduation Year --> 2014
#
# L:College Name --> Vellore Institute of Technology
# L:Degree --> Bachelor of Technology in Information Technology
# L:Location --> Mangalore
# L:Companies worked at --> Infosys Limited
# L:Location --> Mangalore
# L:Companies worked at --> Infosys Limited
# L:Designation --> Senior System Engineer
# L:Email Address --> indeed.com/r/Prakriti-
# Shaurya/5339383f9294887e
# L:Location --> Mangalore
# L:Companies worked at --> Infosys Limited
# L:Designation --> Senior System Engineer
# L:Name --> Prakriti Shaurya
# L:Skills --> CHEF
# L:Skills --> AWS
#
# L:Skills --> AWS
# L:Companies worked at --> Oracle
# L:Skills --> weblogic
# L:Skills --> Docker
# L:Skills --> jenkins
# L:Skills --> devops
# L:Skills -->  maven
# L:Skills --> svn
# L:Skills --> git
# L:Skills --> Linux
# L:Skills --> CHEF
# L:Skills --> AWS
# L:Location --> Hyderabad
# L:Location --> Hyderabad
# L:College Name --> Annamacharya Institute of Technology
# L:Companies worked at --> Oracle
# L:Designation --> Configuration Engineer
# L:Companies worked at --> Oracle
# L:Skills --> Docker
# L:Skills --> Docker
# L:Skills --> CHEF
# L:Skills --> AWS
#
# L:Skills --> AWS
# L:Location --> Hyderabad
# L:Companies worked at --> Oracle
# L:Designation --> Configuration Engineer
# L:Location --> Hyderabad
# L:Skills --> Linux
# L:Companies worked at --> Oracle
# L:Skills --> Linux
# L:Skills --> Linux
# L:Skills --> Linux
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Skills --> Linux
# L:Skills --> Docker
# L:Skills --> AWS
# L:Skills --> Linux
# L:Companies worked at --> Oracle
# L:Skills --> Linux
# L:Skills --> AWS
# L:Skills --> CHEF
# L:Skills --> Linux
# L:Skills --> CHEF
# L:Designation --> Configuration Engineer
# L:Graduation Year --> 2015
# L:Location --> Hyderabad
# L:College Name --> Annamacharya Institute of Technology
# L:Degree --> B.Tech
# L:Skills --> CHEF
# L:Skills --> Configuration Tools
#
# L:Skills --> AWS
#
# L:Skills --> AWS
# L:Skills --> Cloud
#
# L:Skills --> UDeploy,Jenkins
# L:Companies worked at --> Oracle
# L:Skills --> Shell Scripting and Python
#
# L:Skills --> Maven 3
# L:Skills --> Jenkins 1.6, Hudson
# L:Skills --> WebLogic 11g, Apache HTTP Server 2.4
# L:Skills --> Continuous Integration Tools
# L:Skills --> Web/Appservers
# L:Skills --> Subversion(SVN),GIT
#
# L:Skills --> Version Control Tools
#
# L:Graduation Year --> 2015
# L:Location --> Hyderabad
# L:Companies worked at --> Oracle
# L:Designation --> Configuration Engineer
# L:Companies worked at --> Oracle
# L:Skills --> Docker
# L:Skills --> Docker
# L:Skills --> CHEF
# L:Skills --> AWS
#
# L:Skills --> AWS
# L:Email Address --> indeed.com/r/PRASHANTH-BADALA/
# bf4c4b7253a8ece7
# L:Location --> Hyderabad
# L:Companies worked at --> Oracle
# L:Designation --> Cloud Engineer
# L:Designation --> Devops Engineer
# L:Name --> PRASHANTH BADALA
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Skills --> Extension, PLSQL, BI Publisher Reports, Oracle Reports, AP, HRMS, GL, Conversion, Oracle Apps
# technical, Interface, AR, TOAD, OLFM, SQL, FA
#
# ADDITIONAL INFORMATION
#
# Software Skills:
#
# ERP-Oracle Applications 11i, R12
# Accounts Receivable, Accounts Payable, Fixed Assets, General Ledger, Oracle Lease and Finance
# Management, Purchasing and HRMS (Employee, Assignment, Contacts, Pay methods, Job and
# Location)
#
# RDBMS Oracle […]
# LANGUAGES C++
# TOOLS Toad, SQL Developer, Kintana, Report Builder 6i/10g, Discoverer Admin/Desktop/Plus/
# Viewer and BI Publisher
# L:College Name --> Visvesvaraya Technological University
# L:College Name --> Dayanand Sagar College of Engineering
# L:Degree --> Bachelor of Engineering in Engineering
# L:College Name --> Visvesvaraya Technological University
# L:Degree --> B.E
#
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Designation --> Principal Consultant
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Designation --> Principal Consultant
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Companies worked at --> Oracle
# L:Designation --> Principal Consultant
# L:Companies worked at --> Oracle
# L:Location --> Bengaluru
# L:Companies worked at --> Oracle
# L:Designation --> Principal Consultant
# L:Name --> Pratibha P
# L:Companies worked at --> SAP
# L:Companies worked at --> SAP
# L:Skills --> Front End Tool
# Languages
# SAP Technologies HR and Administration Functional Module
# Database FOXPRO 6.22
# Concepts OOP'S, Networking, DBMS, Operating System.
# Operating System MS-Dos […] & MS OFFICE 2007, 2008 & 2010
#
# L:Companies worked at --> SAP
# L:Companies worked at --> SAP
# L:Companies worked at --> SAP
# L:Companies worked at --> SAP
# L:Skills --> HR (10+ years), SAP (10+ years), APPRAISAL (Less than 1 year), BUYING/PROCUREMENT (Less
# than 1 year), DATABASE (Less than 1 year)
# L:Designation --> Officer-HR & Administration in H.& R. Johnson (India)
# L:Companies worked at --> SAP
# L:Companies worked at --> SAP
# L:Location --> Dewas
# L:Companies worked at --> SAP
# L:Designation --> Officer-HR & Administration in H.& R. Johnson (India)
# L:Companies worked at --> SAP
# L:Companies worked at --> SAP
# L:Email Address -->  indeed.com/r/Prem-Koshti/a1fec9e7289496f0
# L:Location --> Dewas
# L:Companies worked at --> SAP
# L:Designation --> Officer-HR & Administration in H.& R. Johnson (India)
# L:Name --> Prem Koshti
# L:Skills --> ✓ ADVANCED MS OFFICE (WORD, POWERPOINT, EXCEL, ETC.)
# ✓ ADOBE PHOTOSHOP, READER X, ACROBAT, COREL DRAW, MICROMEDIA FLASH ETC.
# ✓ JAVA NETBEANS, SQL, HTML, CMD PROMPT, ETC.
# ✓ FAMILIAR WITH ALL SORTS OF WINDOW SETS AND WEB BROWSERS.
# ✓ ALL KINDS OF UTILITY SOFTWARES AND HARDWARE OPTIONS TO INCREASE EFFICIENCY AND
# EFFECTIVENESS IN WORKING.
# ✓ COMPLETE KNOWLEDGE OF MICROSOFT EXCHANGE SERVER 2012.
# ✓ CAN DEVELOP WEBSITES BASED ON HTML, PHP ETC.
# ✓ BASIC KNOWLEDGE OF ANDROID AND MAC APPLICATIONS.
# ✓ COMPLETE KNOWLEDGE OF SERVER AND CLIENT BASED ENVIRONMENT
# ✓ BASIC KNOWLEDGE OF MICROSOFT WINDOWS FIREWALL
# L:Companies worked at --> Cisco
# L:Companies worked at --> Cisco
# L:Skills --> A computer expert with hardware and software grab.
# ✓ Administration and Back-end handling (Technical) on overall basis of the Branch.
# ✓ Convincing people tactfully so as to make the company an option for the user.
# L:Skills --> Firewall (1 year), HTML (1 year), MICROSOFT WINDOWS (1 year), Router (1 year), security. (1
# year)
# L:College Name --> Aptech Institute of Technology
# L:College Name --> Aptech Institute of Technology
# L:Degree --> Computer Networking
# L:College Name --> Karnataka State University
#
# L:Degree --> BACHELOR'S IN SCIENCE in COMPUTER NETWORKING
# L:College Name --> IGNOU
#
# L:Degree -->
# MCL in Computer Application
#
# L:Companies worked at --> Cisco
# L:Companies worked at --> Cisco
# L:Companies worked at --> Cisco
# L:Companies worked at --> Cisco
# L:Email Address --> indeed.com/r/Pulkit-Saxena/ad3f35bfe88a0410
#
# L:Location --> New Delhi
# L:Name --> Pulkit Saxena
# L:Skills -->  Windows and Linux
# L:Skills --> Eclipse, PyCharm
# L:Skills --> Databases: Oracle, Mysql
# L:Skills --> Java, C, C++, Python, Batch
# L:Skills --> python, java
#
# L:Skills -->  HYPERION
# L:Skills --> ESSBASE
# L:Skills --> ECLIPSE
# L:Skills --> DATABASES
# L:Skills --> C++
# L:Graduation Year --> 2017
# L:College Name --> North Maharashtra University
#
# L:Degree --> B.E. in ENC
# L:Graduation Year --> 2017
# L:Companies worked at --> Oracle India Pvt Ltd
# L:Designation --> Associate Software Engineer
#
# L:Email Address --> indeed.com/r/Puneet-Singh/cb1ede9ee6d21bca
#
# L:Location --> Bengaluru
# L:Designation --> Associate Software Engineer
#
# L:Name --> Puneet Singh
# L:Skills --> Scripting Languages: Shell Scripting
# Configuration Management: Ansible.
# Container service: Docker
# L:Skills --> Cloud Technologies: AWS
#
# Operating Systems: Linux, Windows.
# Version Control Systems: GIT
# Automated Build Tools: Maven
# Continuous Integration: Jenkins
# L:Skills --> AWS (3 years), Tomcat, Ansible, git, LAMP, docker, jenkins, Maven, Jira
# L:College Name --> Vaughn College of Aeronautics and Technology
# L:Degree --> Bachelor Of Science
# L:Companies worked at --> Microsoft
# L:Designation --> Process Associate
#
# L:Companies worked at --> HCL Technologies -
#
# L:Designation --> Software Engineer
# L:Designation --> Software Engineer
# L:Years of Experience -->  3.5 years
# L:Location --> Hyderabad
# L:Companies worked at --> Disney
#
# L:Designation --> Software Engineer
# L:Name --> Rahul Bollu
# L:Skills --> TIONAL INFORMATION
#
# Soft Skills
#
# Communicator, Innovator, Team Player, Analytical Collaborator. Intuitive
#
# Technical Skills
# • Google AdWords, Google Analytics, Inbound Marketing, SEO (On-page and Off- page), SEM,
# Facebook Ads and Social
# •Project Management, MS Project Professional
# Media Campaigns (Content Bucketing)
# • Tableau, Microsoft Power BI, SPSS
# • MS Office Suite, Advanced Excel, MS SharePoint, Visio, Adobe Photoshop, Pe
# L:Skills -->  April 2014
#
# SKILLS
#
# Adobe Photoshop (Less than 1 year), Ads (Less than 1 year), BI (1 year), Business Intelligence
# (1 year), MS Excel (2 years), presales (1 year), Tableau (1 year), Pega Marketing and BPM (Less
# than 1 year), MS Word (2 years), MS Powerpoint (2 years), MS Sharepoint (2 years), Spss (Less
# than 1 year), IBM Maximo (Less than 1 year), marketing strategy (2 years), Business Analysis
# (2 years), communication and soft skills (2 years), Project Management (2 years), Project
# Planning (2 years), Team
# L:Companies worked at --> ultant
#
# Infosys -  Pune, Mahara
# L:Designation --> graphy
#
# Associate Con
# L:Companies worked at --> nt
#
# Infosys Lim
# L:Designation --> ior Associate Consult
# L:Designation --> CE
#
# Senior Associate Consul
# L:Years of Experience --> 2 years
# L:Email Address --> Indeed: indeed.com/r/Rajeev-Kumar/3f560fd91275495b
# L:Location --> Bengaluru
# L:Companies worked at --> Infosys/Offshore Lead
# L:Designation --> Senior Associate Consultant
# L:Designation --> Senior Associate Consultant
# L:Name --> Rajeev Kumar
# L:Graduation Year --> 1992
# L:College Name --> Nagarjuna University
# L:Degree --> B.S. in Electronics & Communications Engineering
#
# L:Graduation Year --> 1994
# L:College Name --> Texas A&M University -  Kingsville, TX
#
# L:Degree --> M.S. in Computer Engineering
#
# L:Skills --> UNIX, Windows, Linux
#
# L:Skills --> SQL, PL/SQL, HTML, XML, JAVA, JDK, J2EE, Oracle ADF, Oracle JDeveloper
# L:UNKNOWN --> Oracle 10g, 11g, 12c
# L:Skills --> Relational data modeling, Object Oriented Modeling & Design, UML, SOAP
# L:Companies worked at --> Oracle Inc
# L:Companies worked at --> Oracle Inc
# L:Designation --> Project Lead
#
# L:Companies worked at --> Oracle Inc
# L:Designation --> Principal Applications Developer
#
# L:Companies worked at --> Oracle Inc
# L:Designation --> Senior Development Manager
#
# L:Companies worked at --> Oracle Inc
# L:Designation --> Senior Development Manager
#
# L:Companies worked at --> Oracle Inc
# L:Companies worked at --> Oracle Inc
# L:Companies worked at --> Oracle Inc
# L:Designation --> Software Development Director
# L:Years of Experience --> 22 years
# L:Email Address --> indeed.com/r/Ram-Edupuganti/3ecdecbcba549e21
#
# L:Companies worked at --> Oracle Inc
# L:Companies worked at --> Oracle Inc
# L:Designation --> Software Development Director
# L:Designation --> Software Development Director
# L:Name --> Ram Edupuganti
# L:Skills -->
# Lead genearation, Customer Handling, cold calling, Negotiation, upselling, IT sales, outbound
# calling, Technical Support, sales forcasting, Software sale, product demonstration, cross selling,
# Inside Sales, Technical sales, MS office, software integration, Network Management
#
# L:College Name --> Govt Science College
# L:Degree --> BACHELOR OF SCIENCE in Electronics
# L:College Name --> Dayananda Sagar College of Engineering
# L:Degree --> MCA in COMPUTER APPLICATION
# L:Email Address --> indeed.com/r/Ramesh-HP/95fc615713630c4e
# L:Companies worked at --> SAP ARIBA
# L:Designation --> CES ASSOCIATE CONSULTANT
# L:Email Address --> indeed.com/r/Ramesh-HP/95fc615713630c4e
# L:Location --> Bangalore
# L:Designation --> CES ASSOCIATE CONSULTANT
# L:Name --> Ramesh HP
# L:Skills --> logging
# L:Skills --> Black Box
# L:Companies worked at --> Accenture
# L:Skills --> SQL
# L:Skills --> Database
# L:Skills --> java
# L:Skills --> SDLC&STLC
# L:Skills --> Manual Testing
# L:Skills --> Splunk
# L:Skills --> Nagious
# L:Skills --> SQL
# L:Skills --> logging
# L:Skills --> java
# L:Skills --> Database
# L:Skills --> Black Box
# L:Skills --> Black Box
# L:Graduation Year --> 2010
# L:College Name --> pragathi high school
# L:Graduation Year --> 2012
# L:College Name --> narayana jr.college
# L:Graduation Year --> 2015
# L:College Name --> vasundhara womens
# L:Degree --> BSc in Computer Science
# L:Graduation Year --> 2015
# L:Location --> Hyderabad
# L:Companies worked at --> Accenture
# L:Designation --> Software Engineer
# L:Companies worked at --> Accenture
# L:Companies worked at --> Accenture
# L:Email Address --> indeed.com/r/Ramya-P/00f125c7b9b95a35
#
# L:Location --> Hyderabad
# L:Name --> Ramya. P
# L:Companies worked at --> SAP EWM
# L:Skills -->
# • SAP Knowledge: SAP EWM, SAP WM, SAP SD, SAP MM, SAP AFS, SAP PP, SAP XI
# • Computing languages: SQL, MS-Office, Open office, HTML, PHP
# L:Skills --> Professional competencies
# Business /IT Consulting Configuration/ Support Requirements/ Blue print /Gap Analysis
# Coding/Debugging Change Management Functional/ Technical Spec Design
#
# L:Graduation Year --> 2005
# L:College Name --> Anna University
# L:Degree --> Bachelor of Technology in Information Technology
# L:Graduation Year --> 2007
# L:Graduation Year --> 2005
# L:College Name --> Anna University
# L:Degree --> Master of Engineering in Computer and Communication
# L:Graduation Year --> 2007
# L:Companies worked at --> SAP EWM
# L:Companies worked at --> SAP EWM
# L:Companies worked at --> SAP EWM
# L:Companies worked at --> SAP EWM
# L:Email Address --> indeed.com/r/R-Arunravi/0da1137537d8b159
#
# L:Location --> Bangalore
# L:Companies worked at --> SAP EWM
# L:Designation --> Functional Consultant / WM Lead
# L:Name --> R Arunravi
# L:Companies worked at --> Microsoft
# L:Companies worked at --> Microsoft
# L:Companies worked at --> Microsoft
# L:Companies worked at --> Microsoft
# L:Companies worked at --> Microsoft
# L:Companies worked at --> Microsoft
# L:Companies worked at --> Microsoft
# L:Companies worked at --> Microsoft
# L:Skills --> SCOM
# L:Companies worked at --> Microsoft
# L:Companies worked at --> Microsoft
# L:Companies worked at --> Microsoft
# L:Skills --> Orchestrator SCSM
# L:Skills --> OPERATIONS MANAGER
# L:Skills --> SCOM
# L:Skills --> OPERATIONS MANAGER
# L:College Name --> Pune University
# L:Degree --> B.E.
# L:Companies worked at --> Microsoft
# L:Companies worked at --> Microsoft
# L:Skills --> SCOM
# L:Email Address --> indeed.com/r/Ravi-Shankar/befa180dc0449299
# L:Companies worked at --> Microsoft
# L:Skills --> SCOM
# L:Companies worked at --> Microsoft
# L:Location --> Pune
# L:Location --> Pune
# L:Companies worked at --> Microsoft
# L:Companies worked at --> Microsoft
# L:Location --> Pune
# L:Location --> Pune
# L:Degree --> B.E.
# L:Location --> Pune
# L:Companies worked at --> Microsoft
# ...
# L:Degree --> Bachelor of Technology in Information Technology
# L:Companies worked at --> Infosys Limited
# L:Designation --> System Engineer
# L:Location --> Bangalore
# L:Companies worked at --> Infosys Limited
# L:Designation --> System Engineer
# L:Email Address --> indeed.com/r/Akila-Mohideen/cfe2854527fb6a12
#
# L:Location --> Bangalore
# L:Companies worked at --> Infosys Limited
# L:Designation --> System Engineer
# L:Name --> Akila Mohideen
# L:Skills --> Sql Server,Cloud Computing,OpenStack, OpenShit, AWS,GCP,Azure, ClouStack,KVM,Hyper-
# V,Citrix Xen Server, ESXi, Chef, Ansible, Jenkins, Maven, Sonar Qube, Nexus, Teamcity, Octopus,
# (3 years)
# L:Degree --> Master's
# L:Companies worked at -->  Infosys OpenStack
# L:Designation --> Project Lead
# L:Designation --> Project Lead
# L:Designation --> Project Lead
# L:Companies worked at -->  Infosys OpenStack
# L:Designation --> Project Lead
# L:Email Address -->  indeed.com/r/Ahmad-Bardolia/8e2c49ea8e7dcd27
# L:Companies worked at -->  Infosys OpenStack
# L:Designation --> Project Lead
# L:Name --> Ahmad Bardolia
# L:Skills -->
# Front office executive (1 year)
#
# ADDITIONAL INFORMATION
#
# TECHNICAL SKILL
# • Basic Knowledge of Computer operating
# • MS OFFICE (MS excel, Ms Word and Power Point)
# • With typing speed 25 wpm
# PERSONAL SKILL
# • Positive Attitude
# • Good decision making
# • Good communication skills
# • Confident
# • Have zeal to learn new things
# L:Degree --> Bachelor'
# L:Companies worked at -->  Infosys limited
# L:Designation --> Admin assistant
# L:Email Address -->  indeed.com/r/Puran-Mal/357ea77b3b002be6
# L:Location --> Jaipur
# L:Name --> Puran Mal
# L:Designation --> on: Principal System Engi
# L:Companies worked at --> Infosys
# L:Companies worked at --> Infosys
# L:Skills --> Networking/Platform/Drivers/Vxworks
#
# ADDITIONAL INFORMATION
#
# Key Strengths
# • Over 15 years of experience in Ethernet Data Communication Technology Ethernet Routing
# Switches, Metro Ethernet Routing Switches, Platform and Wireless
# • Good knowledge of Real Time operating Systems (Vxworks) and Drivers
# • Highly skilled in performing analytical and logic building functions to provide feasible solutions
# to problems
# • Brilliant interpersonal coordination and communication skills
# • Competent at leading, managing and training teams on different aspects of data
# communication systems
#
# Technical Skill Set
# SYSTEMS WORKED ON * Data communication -Multi Service Transport Network Controller Cards,
# Ethernet Routing Switch,
# L:College Name --> Board of Technical Education
#
# L:Degree --> B.E. in Computer Science
# L:College Name --> BITS Pilani
# L:Degree --> M.S in Software Systems
#
# L:Companies worked at --> Infosys
# L:Companies worked at --> Aricent Technologies
#
# L:Designation --> Principal System Engineer
# L:Email Address -->  indeed.com/r/Sridevi-H/63703b24aaaa54e4
# L:Location --> Bangalore
# L:Name --> Sridevi H
# L:Skills --> EDD, CDD, credit risk assessment, KYC, Banking, credit risk analysis, Customer Handling,
# Portfolio Management, Customer Service
#
# L:College Name --> West Bengal State University
#
# L:Degree --> Bcom
# L:Email Address --> indeed.com/r/Raktim-Podder/32472fc557546084
# L:Designation --> SME
# L:Companies worked at --> TCS
# L:Designation --> SME
# L:Email Address --> indeed.com/r/Raktim-Podder/32472fc557546084
# L:Location --> Pune
# L:Years of Experience --> 6+
# L:Name --> Raktim Podder
# L:Email Address --> indeed.com/r/Pavithra-M/26f392ec8251143b
# L:Skills --> ADOBE PHOTOSHOP (Less than 1 year), ANDROID (Less than 1 year), APPLICATION SOFTWARE
# (Less than 1 year), C++ (Less than 1 year), CSS (Less than 1 year)
#
# ADDITIONAL INFORMATION
#
# Technical skills:
#
# • Programing Languages: C, C++ and JAVA.
#
# • Databases: MySQL, SQL server (SQLyog)
#
# • Web tools: HTML, CSS.
#
# • Operating Systems: Windows (XP, 8, 8.1, 10), Ubuntu, fedora, Linux.
# L:Designation --> internship
# L:Companies worked at --> Infosys
# L:Companies worked at --> Infosys
# L:Designation --> internship
# L:Companies worked at --> Infosys
# L:Location --> Bengaluru
# L:Email Address --> indeed.com/r/Pavithra-M/26f392ec8251143b
# L:Location --> Bengaluru
# L:Designation --> internship
# L:Companies worked at --> Infosys
# L:Name --> Pavithra M
# L:Skills -->
# Computer Skills
# @ MS-CIT Course passed with 74 % (Microsoft-word, Excel, and Power-point)
# @ Diploma in Financial Accounting with tally 9 Erp. (87%)
# L:Skills --> @ Strong analytical ability @ Good communication skills @ Client relationship management @
# Team player
# L:Degree -->  2011
# L:College Name --> shivaji University
# L:Degree --> B.Com in Accounts
# L:Location --> Pune
# L:Email Address --> indeed.com/r/shrikant-desai/
# cc6430615ce4d44a
# L:Location --> Pune
# L:Companies worked at --> infosys
# L:Designation --> accountant
# L:Name --> shrikant desai
# L:Skills --> file systems (2 years), Linux (2 years), maintenance (2 years), scheduling (2 years)
# L:College Name --> SRIKALAHASTEESWARA INSTITUTE OF TECHNOLOGY
# L:Degree --> Bachelor Of Technology in insurance
# L:Designation -->
# Linux Administrator
#
# L:Location --> Bengaluru
# L:Companies worked at --> Infosys
# L:Companies worked at --> Infosys
# L:Years of Experience --> 2.1 years
# L:Email Address -->  indeed.com/r/Kiran-Kumar/7e76e7a9e62e7ee5
#
# L:Location --> Bengaluru
# L:Companies worked at --> Infosys
# L:Years of Experience --> 2.1 years
# L:Name --> Kiran Kumar
# L:Email Address --> indeed.com/r/Chaban-kumar-Debbarma/bf721c55fb380d19
# L:College Name --> School
# L:Degree --> 10th
# L:Companies worked at --> Microsoft
#
# L:Location --> Tripura
# L:Email Address --> indeed.com/r/Chaban-kumar-Debbarma/bf721c55fb380d19
# L:Location --> Tripura
# L:Name --> Chaban kumar Debbarma
# L:Location --> Amravati
# L:College Name --> Ramkrishna krida High
# L:Location --> Amravati
# L:Skills --> Database:
# MS-Access
# Other:
# Hardware & Networking, Core Java, C, C++
#
# L:Designation --> Microsoft Certified System Engineer
#
# L:Email Address --> indeed.com/r/Akash-
# Gulhane/8b86faac48268d09
# L:Location --> Amravati
# L:Designation --> Microsoft Certified System Engineer
#
# L:Name --> Akash Gulhane
# L:Location --> Tiruchchirappalli
# L:College Name --> Adi Sankara Polytechnic College
# L:Degree --> DCE
# L:Location --> Tiruchchirappalli
# L:College Name --> ST.Joseph college
# L:Graduation Year --> 2011
#
# L:Degree --> Diploma in Challenger info tech
#
# L:Companies worked at --> Microsoft
# L:Designation --> System Administrator (Server)
# L:Companies worked at --> Microsoft
# L:Designation --> System Administrator (Server)
# L:Email Address -->  indeed.com/r/K-
# Siddharth/0023411a049a1441
# L:Location --> Tiruchchirappalli
# L:Companies worked at --> Microsoft
# L:Designation --> System Administrator (Server)
# L:Name --> K. Siddharth
# L:College Name -->
# Indraprastha Public School
# L:Degree --> C.B.S.E
# L:College Name --> Uttrakhand Technical University
#
# L:Degree --> B.TECH in Computer Science Engineering
# L:Graduation Year --> 2012
# L:College Name -->
# Indraprastha Public School
# L:Degree --> C.B.S.E
# L:Designation --> Microsoft technology Associate (MTA)
# L:Location --> Muzaffarnagar
# L:Designation --> Microsoft technology Associate (MTA)
# L:Name --> Shivam Rathi
# L:Email Address --> indeed.com/r/Nitin-Verma/b9e8520147f728d2
# L:Location --> Pune
# L:Companies worked at --> Pune University
# L:Location --> Pune
# L:Degree --> Bachelor of Engineering in EnTC
# L:Email Address --> indeed.com/r/Nitin-Verma/b9e8520147f728d2
# L:Location --> Pune
# L:Designation --> Assisting Microsoft Partners - Exchange Online and Office
# L:Name --> Nitin Verma
# L:College Name --> Acharya Nagarjuna University
# L:Degree --> MBA
# L:College Name --> Acharya Nagarjuna University
# L:Degree --> Certificate in MSC CHEMISTRY
# L:Companies worked at --> Microsoft
#
# Infosys Limited
# L:Designation --> specialist
#
# Technology Process
# L:Email Address --> indeed.com/r/Venkateswara-D/18b373e3b03b371f
#
# L:Designation --> specialist - Technology Process
#
# L:Name --> Venkateswara D
# L:Skills --> asp.net, dynamics ax technical consultant, sql, x++
#
# L:College Name --> Sreenidhi Institute of science and technology
# L:Degree --> BE in Computer science
# L:Designation --> dynamics AX Technical consultant
#
# L:Designation --> Microsoft dynamics AX Technical consultant
# L:Companies worked at --> Microsoft
# L:College Name --> Indian Terrain Fashions Limited -
#
# L:Designation --> Microsoft dynamics AX Technical consultant
# L:Designation --> dynamics AX Technical consultant
#
# L:Designation --> Microsoft dynamics AX Technical consultant
# L:Companies worked at --> Microsoft
# L:Name --> Shivasai Mantri
# L:Skills --> Microsoft DPM, EMC Legato Networker & Symantec Backup Exec
# L:College Name --> Bishop Ambrose College, Bharathiar University
# L:Degree --> B.Sc in Computer Science
#
# L:Companies worked at --> BITS Pilani
# L:Degree --> MS in Systems Engineering in Systems Engineering
#
# L:Designation --> Backup Administrator
# L:Companies worked at --> MICROSOFT
# L:Designation --> Backup Administrator
# L:Designation --> Backup Administrator
# L:Designation --> Backup Administrator
# L:Designation --> Backup Administrator
# L:Email Address --> indeed.com/r/Prasanna-
# Ignatius/1404633e9449f641
# L:Location --> Chennai
# L:Designation --> Backup Administrator
# L:Companies worked at --> MICROSOFT
# L:Name --> Prasanna Ignatius
# L:Location --> Dhule
# L:Email Address --> indeed.com/r/Pankaj-Bhosale/2d6f2e970b9a7ff6
# L:Location --> Dhule
# L:College Name --> Palesh Commerce College
# L:Degree --> M.D.
# L:Graduation Year --> 2014
# L:College Name --> RCPET's I.M.R.D College
# L:Degree --> MCA
# L:Companies worked at --> Softzel Technologies Pvt. Ltd
# L:Designation --> Jr. Developer
# L:Designation --> Microsoft SQL-SERVER
# L:Designation --> Microsoft SQL-SERVER
# L:Email Address --> indeed.com/r/Pankaj-Bhosale/2d6f2e970b9a7ff6
# L:Location --> Dhule
# L:Designation --> Microsoft SQL-SERVER
# L:Name --> Pankaj Bhosale
# L:Email Address --> indeed.com/r/Vinay-Singhal/c15261079a9b5ae7
# L:Skills --> ❖ Smart Working.
# ❖ Fast and keen learner.
# ❖ Works well within a team and also independently.
# ❖ Flexible and high adaptability to new approaches, people and environments.
# ❖ Professional approach and positive attitude.
# ❖ Hard working with abstract thinking.
# ❖ Good personal skills like photography & software issues.
# ❖ Good Communications Skills
# L:Companies worked at --> Convergys
# L:Designation --> Customer Care Associate Microsoft
# L:Email Address --> indeed.com/r/Vinay-Singhal/c15261079a9b5ae7
# L:Location --> New Delhi
# L:Name --> Vinay Singhal
# L:Email Address --> indeed.com/r/Pawan-Nag/e14493f28cb72022
# L:Name --> Pawan Nag
# L:Skills --> Operating Systems:
# L:Degree --> AMIE sec A
# L:Designation --> Certified System Engineer
# L:Designation --> Microsoft
# L:Email Address --> indeed.com/r/Pawan-Nag/e14493f28cb72022
# L:Location --> Delhi
# L:Location --> Delhi
# L:Designation --> Certified System Engineer
# L:Designation --> Microsoft
# L:Name --> Pawan Nag
# L:Skills --> SQL (1 year), HTML (Less than 1 year), INCIDENT MANAGEMENT (Less than 1 year), IT
# INFRASTRUCTURE (Less than 1 year), MS OFFICE (Less than 1 year)
# L:Location --> Ghaziabad
# L:College Name --> Indraprastha Engineering College, Uttar Pradesh Technical University
# L:Degree -->
# Bachelor of Technology in Computer Science Engineering
# L:Email Address --> indeed.com/r/Shivam-
# Sharma/8e4755830666f3b6
# L:Location --> Ghaziabad
# L:Companies worked at --> HCL Technologies
#
# L:Designation --> L1 Analyst in Microsoft project
# L:Name --> Shivam Sharma
# L:Skills --> TALLY MICROSOFT DYNAMIC OPARATER MICIT
#
# L:Companies worked at --> PUNE UNIVERCITY
# L:Degree --> B.COM
#
# L:Designation --> Microsoft Dainamic Software Billing Operator
# L:Location --> Pune
# L:Companies worked at --> Shreenath Engence
# (COFFEEDAY)
#
# L:Designation --> Microsoft Dainamic Software Billing Operator
# L:Name --> Gaikwad Dilip
# L:Skills --> Computer: Proficient in Windows, Word, Excel, Outlook, PowerPoint Language: Fluent in verbal
# and written English, Hindi and Bengali
# L:Skills --> EXCEL (Less than 1 year), OUTLOOK (Less than 1 year), POWERPOINT (Less than 1 year),
# WORD (Less than 1 year)
# L:College Name --> St. Paul's Academy
# L:Degree --> C.B.S.E
# L:College Name --> Army Public School
# L:College Name --> Barrackpore Rastraguru Surendranath College
# L:Degree --> West Bengal State
# L:Degree -->
# B.Sc
# L:College Name --> Ballygunge Science College
# L:Degree --> M.Sc in biology
# L:Degree --> West Bengal State
# L:Degree --> Engineering
# L:Email Address -->  indeed.com/r/Moumita-Mitra/d63c4dc9837860db
#
# L:Name --> Moumita Mitra
# L:Companies worked at --> Shell
# L:Companies worked at --> Shell
# L:Skills --> SAP HANA (4 years), SAP UI5/Fiori (4 years), AngularJs (Less than 1 year), Web Development
# (8 years), Asp.Net (5 years), C# (4 years), SQL Server (3 years), HTML5 (5 years), Javascript (6
# years), CSS3 (6 years), Software Solution Design (2 years), VBA (2 years), SAP BI (2 years)
# L:Degree --> 'O' Level in Computer Application
#
# L:Degree --> 'A' Level in Computer Application
# L:Graduation Year --> 2005
# L:College Name --> University of Calcutta
# L:Degree --> Bachelor of Arts
# L:Graduation Year --> 2013
# L:College Name --> Sikkim Manipal University
# L:Degree --> MBA in Information Technology
# L:Companies worked at --> Shell
# L:Email Address --> indeed.com/r/Suman-Biswas/63db95fe3ae14910
# L:Graduation Year --> 2013
# L:Graduation Year --> 2013
# L:Designation --> Software Engineer
# L:Companies worked at --> Shell
# L:Designation --> Software Engineer
# L:Email Address --> indeed.com/r/Suman-Biswas/63db95fe3ae14910
# L:Location --> Bengaluru
# L:Companies worked at -->  Royal Dutch Shell
#
# L:Designation --> SAP UI5 Lead, Native HANA Developer
# L:Name --> Suman Biswas
# L:College Name --> Government Engineering College Bhuj
# L:Degree --> BE in Environmental Engineering
# L:Location --> Jamnagar
# L:Designation --> Student
# L:Name --> Mansi Thanki
# L:Location --> Delhi
# L:Location --> Delhi
# L:Location --> Delhi
# L:Location --> Delhi
# L:Location --> Delhi
# L:Skills --> DATA BACKUP (1 year), EXCHANGE (1 year), LAN (1 year), MAINTENANCE (1 year), SAP (1 year)
# L:Designation --> Microsoft Azure (Basic Management)
# L:Designation --> Microsoft Azure (Basic Management)
# L:Email Address --> indeed.com/r/Anil-Kumar/96983a9dd7222ae5
#
# L:Location --> Delhi
# L:Location --> Delhi
# L:Designation --> Microsoft Azure (Basic Management)
# L:Name --> Anil Kumar
# L:Skills --> AUDITING (Less than 1 year), CFA (Less than 1 year), DERIVATIVES (Less than 1 year),
# FINANCIAL ANALYST (Less than 1 year), FINANCIAL STATEMENT ANALYSIS (Less than 1 year)
#
# L:Designation --> Microsoft Office Suite - Expert
# L:Email Address --> indeed.com/r/Siddharth-
# Choudhary/19d56a964e37fa1a
# L:Location --> Hyderabad
# L:Designation --> Microsoft Office Suite - Expert
# L:Name --> Siddharth Choudhary
# L:Skills --> Excel (10+ years), Operations (7 years), Project management (5 years)
# L:Graduation Year --> 2002
# L:College Name --> Ramakrishna College
# L:Degree --> B.Sc. in Biochemistry in Biochemistry
#
# L:Years of Experience --> 2004
# L:College Name --> Bharathiar University
# L:Degree --> Master of Science in Bio Informatics in Bio Informatics
# L:Years of Experience --> 2004
# L:Location --> Bengaluru
# L:Companies worked at --> Infosys BPO Ltd
# L:Location --> Bengaluru
# L:Companies worked at --> Infosys BPO Ltd
# L:Location --> Bengaluru
# L:Companies worked at --> Infosys BPO Ltd
# L:Location --> Bengaluru
# L:Companies worked at --> Infosys BPO Ltd
# L:Location --> Bengaluru
# L:Companies worked at --> Infosys BPO Ltd
# L:Designation --> PMO
# L:Location --> Bengaluru
# L:Companies worked at --> Infosys BPO Ltd
# L:Designation --> PMO
# L:Location --> Bengaluru
# L:Companies worked at --> Infosys BPO Ltd
# L:Designation --> PMO
# L:Companies worked at --> Infosys BPO Ltd
# L:Designation --> PMO
# L:Email Address -->  indeed.com/r/Valarmathi-Dhandapani/
# a2b3eb340068764d
# L:Location --> Bengaluru
# L:Designation --> PMO
# L:Designation --> Investment Banking Operations/PMO
#
# L:Name --> Valarmathi Dhandapani
# L:Skills --> Splunk, Network Security, Arc sight (2 years), SIEM (2 years), McAfee ESM (1 year)
# L:College Name --> Jawaharlal Nehru Technological University
# L:Degree --> B- Tech
#
# L:Designation --> Security Analyst
# L:Companies worked at --> Infosys - Career Contour
# L:Designation --> Security Analyst
# L:Name --> Pradeep Kumar
